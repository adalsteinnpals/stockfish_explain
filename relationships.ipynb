# %% [markdown]
# # Relationship between pieces

# %%
from create_heatmap import main_heatmap
from separate_eval import main_separate
import matplotlib.pyplot as plt

# %%
fen_strings = ["3q2k1/5b1p/1pr2pp1/p2p4/3P2PP/1P1NQP2/P2R2K1/8 w - - 0 1",
               "3q2k1/5b1p/1pr2pp1/p2p4/3P3P/1P1NQP2/P2R2K1/8 w - - 0 1"]
include_pieces = 'A'
method = 'shapley'

fig0 = main_heatmap(fen_strings[0], include_pieces, method)
fig1 = main_heatmap(fen_strings[1], include_pieces, method)
#plt.show()
# Out:
# ...
# Shapley Value Sampling attribution: 100%|██████████| 851/851 [01:07<00:00, 12.61it/s]

# %%
fen_strings = ["3q2k1/5b1p/1pr2pp1/p2p4/3P2PP/1P1NQP2/P2R2K1/8 w - - 0 1",
               "3q2k1/5b1p/1pr2pp1/p2p4/3P3P/1P1NQP2/P2R2K1/8 w - - 0 1"]
include_pieces = 'A'
method = 'shapley'
separate = 'Y'

fig0 = main_separate(fen_strings[0], include_pieces, method, separate)
fig1 = main_separate(fen_strings[1], include_pieces, method, separate)
